# %% [markdown]
# # Naver API

# %% [markdown]
# ## 1. 블로그 검색

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "SGLHGjPZGSsFRhhdmqyJ"
client_secret = "ECpkEOboRw"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><rss version="2.0"><channel><title>Naver Open API - blog ::&apos;파이썬&apos;</title><link>https://search.naver.com</link><description>Naver Search Result</description><lastBuildDate>Wed, 09 Oct 2024 00:34:00 +0900</lastBuildDate><total>497235</total><start>1</start><display>10</display><item><title>[&lt;b&gt;파이썬&lt;/b&gt; 기초 강의]-&lt;b&gt;파이썬&lt;/b&gt; 기본 자료형(Primitive Types) 및... </title><link>https://esajin.kr/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EA%B8%B0%EC%B4%88-%EA%B0%95%EC%9D%98-%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EA%B8%B0%EB%B3%B8-%EC%9E%90%EB%A3%8C%ED%98%95Primitive-Types-%EB%B0%8F-%EC%A3%BC%EC%84%9D-%EC%B2%98%EB%A6%AC-%EC%9D%B4%ED%95%B4%ED%95%98%EA%B8%B0-007%EA%B0%95?category=733629</link><description>쓰기 &lt;b&gt;파이썬&lt;/b&gt;에서는 크게 두 가지의 자료형 중에서 기본 자료형(Primitive Types)에 대해 설명... &lt;b&gt;파이썬&lt;/b&gt;에서 자료형(Data type)은 지난 시간에 배웠던, 변수가 저장할 수 있는 값의 유형을 유형을 말하는... </description><bloggername>서관덕의 시간이 머문 작은 공간</bloggername><bloggerlink>https://esajin.kr/</bloggerlink><postdate>20240926</postdate></item><item><title>&lt;b&gt;파이썬&lt;/b&gt;강의 기초 이론과 실무 수업!</title><link>https://blog.naver.com/dmsdud0395/223521719198</link><description>그래서 언젠가는 &lt;b&gt;파이썬&lt;/b&gt;강의를 한 번 들어봐야겠다고 생각을 했었는데 마침 여러 가지로 여건이... Python(&lt;b&gt;파이썬&lt;/b&gt;)이란? &lt;b&gt;파이썬&lt;/b&gt;이라는 것이 생소하게 느껴지는 분들이 계실 것 같아서 우선 이에 대한 소개부터... </description><bloggername>그럼에도 불구하고..</bloggername><bloggerlink>blog.naver.com/dmsdud0395</bloggerlink><postdate>20240722</postdate></item><item><title>부산&lt;b&gt;파이썬&lt;/b&gt;학원, 도전한 후기!</title><link>https://blog.naver.com/wldnek03/223479755700</link><description>[부산&lt;b&gt;파이썬&lt;/b&gt;학원] 기본 이론부터 실전까지! 문과를 전공했지만, 지난 몇 년 사이에 취업의 문이 극도로... 부산&lt;b&gt;파이썬&lt;/b&gt;학원에 다니면서 자격증도 따고, 코딩을 배워서 앞으로 무엇을 할 것인지 어느 정도 가닥도... </description><bloggername>JOO</bloggername><bloggerlink>blog.naver.com/wldnek03</bloggerlink><postdate>20240614</postdate></item><item><title>안산코딩학원 취업을 위한, &lt;b&gt;파이썬&lt;/b&gt; 공부과정</title><link>https://blog.naver.com/thfk8158/223557390118</link><description>그리고 제가 선택한 분야는 바로 &lt;b&gt;파이썬&lt;/b&gt;이라는 프로그래밍 언어였는데, 마침 저에게 적합한 안산코딩학원이 있어서 공부를 시작하게 됐고 기초부터 탄탄하게 배우며 스킬을 늘리고 있는 중이에요. &lt;b&gt;파이썬&lt;/b&gt;(python)... </description><bloggername>순간을 영원히,</bloggername><bloggerlink>blog.naver.com/thfk8158</bloggerlink><postdate>20240822</postdate></item><item><title>&lt;b&gt;파이썬&lt;/b&gt;전문가 자격증 종류 및 시험정보 모음</title><link>https://blog.naver.com/magicbox35/223532134868</link><description>&lt;b&gt;파이썬&lt;/b&gt;전문가 자격증 종류 및 시험정보 모음 1인 1컴퓨터의 시대를 지나 이젠 1인 2컴퓨터의 시대를... 오늘은 보다 전문적인 &lt;b&gt;파이썬&lt;/b&gt;전문가 자격에 대해 소개할까 합니다. 자격증 종류 및 시험정보도 모음으로... </description><bloggername>미래를 설계하는 재훈님의 블로그</bloggername><bloggerlink>blog.naver.com/magicbox35</bloggerlink><postdate>20240801</postdate></item><item><title>&lt;b&gt;파이썬&lt;/b&gt;전문가 자격증 종류 체계적인 취득방법</title><link>https://blog.naver.com/colabovlog/223532391042</link><description>&lt;b&gt;파이썬&lt;/b&gt;전문가 자격증 종류 체계적인 취득방법 반갑습니다. 이번 시간에 알려드릴 내용은 &lt;b&gt;파이썬&lt;/b&gt;전문가 자격증입니다! &lt;b&gt;파이썬&lt;/b&gt;에 대해 알고 계시거나 관심 있으신 분들이 들어오셨을 거라 생각합니다. 컴퓨터... </description><bloggername>콜라보리누나</bloggername><bloggerlink>blog.naver.com/colabovlog</bloggerlink><postdate>20240801</postdate></item><item><title>&amp;lt;부산&lt;b&gt;파이썬&lt;/b&gt;학원&amp;gt; 실무 위주 자격증 수업!</title><link>https://blog.naver.com/dnjswlgh928/223483720634</link><description>부산&lt;b&gt;파이썬&lt;/b&gt;학원에 등록했습니다. 체계적인 커리큘럼 학원을 고를 때는 커리큘럼 구성이 탄탄하고... 며칠 동안 검색하고 주변에 수소문한 끝에 이러한 조건에 딱 맞는 부산&lt;b&gt;파이썬&lt;/b&gt;학원을 찾아냈어요. 그래서... </description><bloggername>Twinkle Yebin House</bloggername><bloggerlink>blog.naver.com/dnjswlgh928</bloggerlink><postdate>20240618</postdate></item><item><title>&lt;b&gt;파이썬&lt;/b&gt;전문가 자격증 전문가 과정 학습</title><link>https://blog.naver.com/rudolph77/223532016252</link><description>&lt;b&gt;파이썬&lt;/b&gt;전문가 자격증 전문가 과정 학습 안녕하세요. 오늘은 &lt;b&gt;파이썬&lt;/b&gt;전문가 자격증에 대해서 알아보겠습니다. 다들 자바칩이나 &lt;b&gt;파이썬&lt;/b&gt; 등 IT 관련 용어는 많이 들어보셨을 거라고 생각해요. 저도 학교에서... </description><bloggername>rudolfio</blog ...

# %% [markdown]
# ## 2. 책 검색

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "SGLHGjPZGSsFRhhdmqyJ"
client_secret = "ECpkEOboRw"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 09 Oct 2024 00:28:52 +0900",
# 	"total":1035,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"파이썬의 엑셀, 판다스 라이브러리 (엑셀 예제로 배우는 파이썬 데이터 분석)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/50382721627",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_5038272\/50382721627.20240921091748.jpg",
# 			"author":"김판다",
# 			"discount":"36000",
# 			"publisher":"비제이퍼블릭",
# 			"pubdate":"20240930",
# 			"isbn":"9791165922962",
# 			"description":"‘파이썬의 엑셀’이라 불리는 판다스 라이브러리는 데이터 분석가가 아니어도 배워볼 만한 가치가 충분하다. 데이터를 다루지만 엑셀의 한계를 느낀다면 판다스를 배워보자. 특히 마이크로소프트 엑셀에 파이썬이 탑재되었기에 더욱 그러하다. 또한 파이썬으로 데이터 분석에 입문하고자 한다면 판다스는 좋은 선택이다.\n\n이 책은 판다스의 기초적 수준에서 시작하여 실전 데이터 분석을 위해 알아야 하는 필수적인 개념, 기능, 함수, 라이브러리 등을 다룬다. 다양한 예제와 그림 자료를 바탕으로 친절하게 설명하여 입문자도 쉽게 배울 수 있고, 판다스의 핵심이 되는 내용들을 세심하게 정리하였기에 판다스를 아는 사람이라도 지식의 빈틈을 메꿀 기회가 될 것이다. 또한 데이터 분석의 효율성을 높이는 심화 팁과 데이터 분석의 감을 잡을 수 있는 실전 데이터 분석 경험을 제공한다."
# 		},
# 		{
# 			"title":"혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32507605957",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3250760\/32507605957.20230509170119.jpg",
# 			"author":"윤인성",
# 			"discount":"19800",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20220601",
# 			"isbn":"9791162245651",
# 			"description":"혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서\n\n『혼자 공부하는 파이썬』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별 학습은 그대로! 혼자 공부하더라도 체계적으로 계획을 세워 학습할 수 있도록 ‘혼공 계획표’를 새롭게 추가했습니다. 또한 입문자가 자주 물어보는 질문과 오류 해결 방법을 적재적소에 배치하여 예상치 못한 문제에 부딪혀도 좌절하지 않고 끝까지 완독할 수 있도록 도와줍니다. 단순한 문법 암기와 코딩 따라하기에 지쳤다면, 새로운 혼공파와 함께 ‘누적 예제’와 ‘도전 문제’로 프로그래밍의 신세계를 경험해 보세요! 배운 내용을 씹고 뜯고 맛보고 즐기다 보면 응용력은 물론 알고리즘 사고력까지 키워 코딩 실력이 쑥쑥 성장할 것입니다.\n\n이 책은 독학으로 파이썬을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘 모르는지조차 모르는 입문자의 막연한 마음에 십분 공감하여 과외 선생님이 알려주듯 친절하게, 핵심적인 내용만 콕콕 집어줍니다. 책의 첫 페이지를 펼쳐서 마지막 페이지를 덮을 때까지, 혼자서도 충분히 파이썬을 배울 수 있다는 자신감과 확신이 계속될 것입니다!\n\n베타리더와 함께 입문자에게 맞는 난이도, 분량, 학습 요소 등을 적극 반영했습니다. 어려운 용어와 개념은 한 번 더 풀어쓰고, 복잡한 설명은 눈에 잘 들어오는 그림으로 풀어냈습니다. ‘혼자 공부해 본’ 여러 입문자의 초심과 눈높이가 책 곳곳에 반영된 것이 이 책의 가장 큰 장점입니다."
# 		},
# 		{
# 			"title":"Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/40354085633",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4035408\/40354085633.20230927071024.jpg",
# 			"author":"박응용",
# 			"discount":"19800",
# 			"publisher":"이지스퍼블리싱",
# 			"pubdate":"20230615",
# 			"isbn":"9791163034735",
# 			"description":"프로그래밍 분야 8년 연속 베스트셀러!\n《Do it! 점프 투 파이썬》 전면 개정 2판 출시!\n\n중고등학생도, 비전공자도, 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이 전면 개정 2판으로 새롭게 태어났다! 챗GPT를 시작으로 펼쳐진 생성 AI 시대에 맞춰 설명과 예제를 다듬고, 최신 경향과 심화 내용을 보충했다. 또한 이번 개정 2판도 50만 코딩 유튜버인 조코딩과 협업을 통해 유튜브 동영상을 제공해 파이썬을 더 쉽게 공부할 수 있다.\n\n8년 연속 베스트셀러! 위키독스 누적 방문 300만! 독자의 입에서 입으로 전해진 추천과 수많은 대학 및 학원의 교재 채택을 통해 검증은 이미 끝났다. 코딩을 처음 배우는 중고등학생부터 코딩 소양을 기르려는 비전공자, 자기계발에 진심인 직장인까지! 이 책과 함께 파이썬 프로그래밍의 세계로 ‘점프’해 보자!"
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32438172833",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243817\/32438172833.20230920072917.jpg",
# 			"author":"김영천",
# 			"discount":"23750",
# 			"publisher":"기한재",
# 			"pubdate":"20200225",
# 			"isbn":"9788970187990",
# 			"description":"▶ 이 책은 Python(파이썬)을 다룬 이론서입니다. Python(파이썬)의 기초적이고 전반적인 내용을 학습할 수 있습니다."
# 		},
# 		{
# 			"title":"CODING BASICS PYTHON (파이썬)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32440944646",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3244094\/32440944646.20230509164030.jpg",
# 			"author":"김상민^장성식^김일태",
# 			"discount":"18000",
# 			"publisher":"렉스미디어닷넷",
# 			"pubdate":"20220210",
# 			"isbn":"9788959604210",
# 			"description":"파이썬으로 다지는 프로그래밍의 기초\n\nㆍ 다양한 예제를 활용하여 초보자도 쉽게 프로그래밍의 기본을 익힐 수 있는 파이썬 입문서입니다.\nㆍ 문법을 사전식으로 나열하지 않고 기능적인 프로그램을 하나씩 완성하면서 익힐 수 있게 구성했습니다.\nㆍ 단계별로 완성하는 장별 예제 및 연습문제를 바탕으로 자신만의 프로그램을 완성할 수 있습니다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32489150082",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3248915\/32489150082.20230207165503.jpg",
# 			"author":"천인국",
# 			"discount":"11640",
# 			"publisher":"인피니티북스",
# 			"pubdate":"20170830",
# 			"isbn":"9791185578330",
# 			"description":"컴퓨팅 사고(Computational Thinking)는 자넷 윙 교수가 2006년에 컴퓨터 학술지에서 언급한 이후로 컴퓨터 교육 분야에서 상당한 이슈가 되고 있는 용어이다. 컴퓨팅 사고는 복잡한 문제를 분해하여 문제 안에 내재된 패턴을 찾고 추상화 단계를 거쳐서 문제를 해결하는 알고리즘을 작성하는 과정이다. 작성된 알고리즘은 사람이 수행하거나 컴퓨터를 이용하여 자동화될 수 있다. \n이 책은 컴퓨팅 사고와 파이썬을 동시에 학습할 수 있도록 기획되었다. 파이썬은 컴퓨터를 전공하지 않은 학생들도 쉽게 사용할 수 있다는 큰 장점이 있다. 컴퓨팅 사고는 흥미로운 실습 예제가 많이 필요하다. 이 책에서는 최대한 많은 실습 예제를 간추려서 파이썬으로 실습할 수 있도록 하였다. 파이썬은 다양한 애니메이션이나 가상 실습을 만들 수 있는 최적의 도구이다. 학생들은 파이썬을 통하여 컴퓨터 프로그래밍의 기본적인 개념들과 컴퓨팅 사고에서 나타나는 다양한 실습을 수행할 수 있을 것이다."
# 		},
# 		{
# 			"title":"파이썬 (비전공자를위한 파이썬 기초 입문서)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32436003648",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243600\/32436003648.20230920072841.jpg",
# 			"author":"김명호",
# 			"discount":"16200",
# 			"publisher":"에듀웨이",
# 			"pubdate":"20190525",
# 			"isbn":"9791186179369",
# 			"description":"막막했던 파이썬, 이제 한 권으로 기초를 배우는\n파이썬 사용 설명서!\n\n전 세계적으로 유명한 구글(Google)이 자신의 많은 서비스를 파이썬으로 제공하고 있습니다. 이것은 구글의 뛰어난 서비스를 개인의 비즈니스에 쉽게 이용할 수 있다는 의미입니다.  이러한 발전에 맞춰 파이썬 문법의 기초를 쉽게 이해할 수 있도록 이 책에서는 친절한 도해와 함께 코딩 개념을 설명합니다. 파이썬을 처음 배우는 학생부터 비전공자, 코딩 실력을 높이려는 직장인까지 기본 문법부터 예제를 통한 활용 실력을 높여 파이썬 프로그래밍을 마스터할 수 있습니다. 가장 쉽고, 빠르게, 효율적인 파이썬 사용 설명서! ‘한 권으로 끝내는 파이썬’에서 찾아보세요."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32460987987",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3246098\/32460987987.20230207163755.jpg",
# 			"author":"홍의경",
# 			"discount":"29440",
# 			"publisher":"생능출판",
# 			"pubdate":"20220309",
# 			"isbn":"9788970506784",
# 			"description":"코딩 실력을 키우는 지름길은 실습이다.\n\n2008년 즈음에 검인정 중학교 교과서 정보1, 정보2, 정보3을 공저로 저술하였습니다. 그 당시에 8종류의 교과서가 검인정에 합격하였는데, 파이썬을 기반으로 하는 교과서가 2종류, C언어를 기반으로 하는 교과서가 2종류, 베이직을 기반으로 하는 교과서가 2종류, 스크래치를 기반으로 하는 교과서가 2종류였습니다.\n\n교육용 언어로 시작한 파이썬이 중학교 학생들이 비교적 쉽게 학습할 수 있는 프로그래밍 언어라고 생각했는데 10여년의 세월이 흐른 지금 파이썬이 활용되는 분야가 가히 폭발적으로 증가하였습니다. \n\n파이썬에 관한 쉽고 좋은 교재를 저술하기 위해서 인터넷에서 30,000페이지 이상의 자료를 찾아서 검토하였습니다. 어쩌면 파이썬이 첫 프로그래밍 언어일 본 교재의 독자들이 두려움 없이 파이썬을 기초부터 쉽게 공부하다가, 교재를 다 읽고 나면 “어느새 중급 수준에 도달했구나”라는 생각이 들도록  완성도 높은 교재를 목표로 하였습니다. \n\n입문자를 대상으로 하는 교재일수록 집필하는데 훨씬 더 많은 정성과 노력이 필요하다는 것을 잘 알고 있습니다. 개인적으로는 데이터베이스 전공교재를 저술할 때보다 몇 배 더 힘들었고, 공을 많이 들였습니다. \n\n원고를 버전 9까지 작성하는 동안 셀 수 없이 원고를 읽어보면서 꼭 필요하지 않은 문장은 삭제하고, 필요한 문장은 반드시 넣었습니다. 고등학교 검인정 교과서 1권, 중학교 검인정 교과서 3권, 데이터베이스 전공 교재 2권, 엑셀 교재 1권, 번역서 2권을 집필하면서 나름대로 한글을 정확하고 간결하게 표현하는데 자신이 있습니다."
# 		},
# 		{
# 			"title":"파이썬 (제2판)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32436240934",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243624\/32436240934.20230928092006.jpg",
# 			"author":"염기원^오지영",
# 			"discount":"16200",
# 			"publisher":"북두",
# 			"pubdate":"20220120",
# 			"isbn":"9791166750991",
# 			"description":"책의 전반부는 비전공자의 입장에서 비전공자를 위한 파이썬 프로그래밍의 기초적인 내용으로 구성되어 있다. 프로그래밍에 익숙하거나 파이썬 경험이 있는 독자들은 곧바로 책의 후반부를 공부하는 것을 권한다. 책의 전반부에서는 저자가 처음 컴퓨터 프로그래밍이라는 것을 배울 때 가장 어려워했던 변수와 메모리 관계, 특성에 대해서 상세하게 설명하면서 비전공자들이 쉽게 프로그래밍에 입문할 수 있도록 하였다. 대부분의 프로그래밍 교재와 다를바 없이, 파이썬으로 프로그램을 작성할 수 있도록 개발환경을 설치하는 과정과 사용 가능한 프로그래밍 툴에 대해서도 빠지지 않고 최대한 상세한 설명과 충분한 그림을 삽입하였다. 또한, 전반부의 뒷부분은 데이터 분석에 필요한 파이썬 프로그램 위주로 구성해서 앞부분의 기초 프로그래밍 지식을 바탕으로 본격적인 데이터 분석을 위한 토대를 마련할 수 있도록 구성하였다."
# 		},
# 		{
# 			"title":"파이썬",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32438301029",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243830\/32438301029.20240815214302.jpg",
# 			"author":"임정목",
# 			"discount":"17100",
# 			"publisher":"현우사",
# 			"pubdate":"20180305",
# 			"isbn":"9788980815180",
# 			"description":"▶ 이 책은 실습을 통해 쉽게 배우는 파이썬에 대해 다룬 도서입니다. 파이썬의 기초적이고 전반적인 내용을 확인할 수 있도록 구성했습니다."
# 		}
# 	]
# }

# %%
print(request)
# Out:
# <urllib.request.Request object at 0x111e5b3d0>

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request

client_id = "SGLHGjPZGSsFRhhdmqyJ"
client_secret = "ECpkEOboRw"

encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/blog.json?query=" + encText + \
    "&display=100&strat=10&sort=date"  # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 09 Oct 2024 00:46:01 +0900",
# 	"total":497235,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"[CFA] CFA Level 1 Passed, 50일 상위 10% 합격 자세한... ",
# 			"link":"https:\/\/blog.naver.com\/kimjune2020\/223612087588",
# 			"description":"CFA 홈페이지에서 제공하는 <b>파이썬<\/b>이나 Financial Modeling 관련 강의를 수료해야 시험 결과를 받아볼 수 있다. 시험 전에 수강해도 되고, 시험 후에는 시험 결과가 나오기 전에 수강하면 되고, 혹시 그때까지... ",
# 			"bloggername":"매일 꾸준하게 성장하는 사람",
# 			"bloggerlink":"blog.naver.com\/kimjune2020",
# 			"postdate":"20241009"
# 		},
# 		{
# 			"title":"둔산동코딩학원, 연봉 4000 풀스택 개발자 취업까지 6개월?",
# 			"link":"https:\/\/blog.naver.com\/anc9511\/223612077591",
# 			"description":"백엔드 언어로 둔산동코딩학원 에서 배울 수 있는 건 C언어, 자바, <b>파이썬<\/b> 3가지가 있습니다 !!... 것 <b>파이썬<\/b>(Python)은 기초 알고리즘, MVC, 객체, 그래픽 프로그래밍 등의 주요 요소의 프로그래밍 언어 각각의... ",
# 			"bloggername":"정보가 쏟아지는 곳, 여기",
# 			"bloggerlink":"blog.naver.com\/anc9511",
# 			"postdate":"20241009"
# 		},
# 		{
# 			"title":"AI GPT <b>파이썬<\/b> 코드남 8강 패키지 쓰면 뭐든 할 수 있지",
# 			"link":"https:\/\/blog.naver.com\/nojayoun\/223612072890",
# 			"description":"통해 <b>파이썬<\/b>의 다양한 기능을 활용하는 방법을 설명합니다. 강사는 코딩의 기본 원리와 패키지... 터미널이나 <b>파이썬<\/b> 패키지 관리자를 통해 설치한다. pandas와 함께 사용하여 엑셀 데이터를 읽고 쓸... ",
# 			"bloggername":"AI GPT 파이썬",
# 			"bloggerlink":"blog.naver.com\/nojayoun",
# 			"postdate":"20241009"
# 		},
# 		{
# 			"title":"인공지능과 딥러닝모델 (1)",
# 			"link":"https:\/\/blog.naver.com\/mcrobotpower\/223612071510",
# 			"description":"AI 구현 방법들 AI를 구현하는 방법들에는 크게 3가지로 구분할 수 있습니다. 해당 3가지는 기호 처리, 비기호 처리, 혼합\/통합적 처리로 구분되고 각각에 대해서 알아보면 다음과 같습니다. 1.... ",
# 			"bloggername":"하루살이",
# 			"bloggerlink":"blog.naver.com\/mcrobotpower",
# 			"postdate":"20241009"
# 		},
# 		{
# 			"title":"본격적으로 들어가기 전에..",
# 			"link":"https:\/\/blog.naver.com\/mcrobotpower\/223612068446",
# 			"description":"<b>파이썬<\/b>기반AI입문을 다음으로 2학년 2학기에 배웠던 논리추론에 대해서 공부해보려고 합니다. 자료 출처는 2023학년도 2학년 2학기 전공 논리추론이고요 열심히 달려보도록 하겠습니다.",
# 			"bloggername":"하루살이",
# 			"bloggerlink":"blog.naver.com\/mcrobotpower",
# 			"postdate":"20241009"
# 		},
# 		{
# 			"title":"비전공자도 배울 수 있는 <b>파이썬<\/b> 에이콘아카데미 홍대학원",
# 			"link":"https:\/\/blog.naver.com\/gh220a\/223612055127",
# 			"description":"특히, <b>파이썬<\/b>, R 프로그래밍, 머신러닝, 딥러닝 등의 최신 기술을 심도 있게 배워 실무에서 바로 활용할 수 있는 능력을 기를 수 있습니다. 이런 기술들은 현재 IT와 데이터 분석 분야에서 가장 많이 요구되는... ",
# 			"bloggername":"긍정적인 마인드를 갖자",
# 			"bloggerlink":"blog.naver.com\/gh220a",
# 			"postdate":"20241009"
# 		},
# 		{
# 			"title":"샐피 고구마피자 감성 모르는 사람 나가라",
# 			"link":"https:\/\/blog.naver.com\/seyeon0727\/223612052144",
# 			"description":"지지난주에 첫 진도 나가고 오늘 두번짼데 <b>파이썬<\/b> 하나도 기억 안나서 동아리 가기 전에 피피티 보면서 복습 대충 해서 갔다 잇빗 가는중 근데 가자마자 3주차에 실습 덜 한거 해보라 그래서 집에서 문제 좀... ",
# 			"bloggername":"0727",
# 			"bloggerlink":"blog.naver.com\/seyeon0727",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"정보 제공형 제목",
# 			"link":"https:\/\/blog.naver.com\/proof10262\/223612050884",
# 			"description":"입문: <b>파이썬<\/b> 기초부터 실무 활용까지 배우는 완벽 가이드' 정보 제공형 제목은 단순히 콘텐츠의 이름을 짓는 것을 넘어, 독자의 참여를 유도하고, 콘텐츠의 가치를 극대화하는 중요한 요소입니다. 명확성, 가치... ",
# 			"bloggername":"우당탕탕치킨",
# 			"bloggerlink":"blog.naver.com\/proof10262",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"#10월8일 취준생의 수영하고 스크래치 코딩 강의 들은 하루... ",
# 			"link":"https:\/\/blog.naver.com\/dmsgk3636\/223612044490",
# 			"description":"스크레치와 <b>파이썬<\/b> c++언어 등등 코딩 관련 강의를 듣고있는데요! 그중에서도 아래에는 스크레치를 배우면서 만든 프로젝트입니다.:) 간단해서 초보자들이 만들기에 쉬운 기초 코딩프로그램이랍니다.... ",
# 			"bloggername":"오늘의 로고",
# 			"bloggerlink":"blog.naver.com\/dmsgk3636",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2024.10.08(화) 슈퍼코딩 신입연수원 2주차 Day 2 후기",
# 			"link":"https:\/\/blog.naver.com\/qkrwhdtj0209\/223612038915",
# 			"description":"이후 기본적인 백엔드 개념과 <b>파이썬<\/b>에 대해 조금 배웠다 백엔드: 필요한 데이터를 처리하는... 앞폴더이름 이런식으로 경로를 지정해 주거나 vscode에서 처음 폴더를 열 때 저 <b>파이썬<\/b> 파일이... ",
# 			"bloggername":"whdtj0209's blog",
# 			"bloggerlink":"blog.naver.com\/qkrwhdtj0209",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[GIS]Local Moran's I를 활용한 LISA 분석 예시(Python)",
# 			"link":"https:\/\/blog.naver.com\/spatioscopus\/223612037335",
# 			"description":"Local Moran's I란? Local Moran's I는 공간 데이터를 분석할 때 각 지역의 값이 주변 지역과 얼마나 유사한지 측정하는 공간 통계량이다. 이는 특정 지역의 값이 주변 지역의 값들과 비슷하게 군집을... ",
# 			"bloggername":"spatioscopus",
# 			"bloggerlink":"blog.naver.com\/spatioscopus",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"일반화학실험 실험보고서 : 화학양론과 한계반응물 날로먹기... ",
# 			"link":"https:\/\/blog.naver.com\/dhbae05\/223612036259",
# 			"description":"이번 실험은 실험 자체도 복잡하고 결과데이터에 대한 가공 및 해석도 반복적인 요소가 많기에 <b>파이썬<\/b>의 다양한 라이브러리로 자동화 시켜 보려 합니다! 그전에 예비보고서는 자료조사 노가다... ",
# 			"bloggername":"과제 20분 컷하고 놀러 가기",
# 			"bloggerlink":"blog.naver.com\/dhbae05",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"이거 하고 저거 하고",
# 			"link":"https:\/\/blog.naver.com\/tkdrbs0802\/223612034737",
# 			"description":"그래도 1일 1코딩은 해야지... :( 자바 주 언어인데 <b>파이썬<\/b> 어렵다. 퉤퉤 그냥 내년에 한 번 읽어보려고 기록한다. 인용구에 대충 점만 찍으면 명언이래써 #브라운돈까스 #앞날창창 #반짝반짝 #Leetcode #<b>파이썬<\/b> #자바",
# 			"bloggername":"세상님은 덤비시오",
# 			"bloggerlink":"blog.naver.com\/tkdrbs0802",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"로또 1141회차 번호 선택 (24\/10\/12, 토), 복덩이 아들이... ",
# 			"link":"https:\/\/blog.naver.com\/kkang2yah\/223612033717",
# 			"description":"번호 추첨: 고정수, 제외수를 정했으니 블로그내 Lotto6Out <b>파이썬<\/b> 코드를 사용하여 무작위 다회 랜덤 추첨을 시행했습니다. (코드는 text 기반 python 코드로 사용자가 고정수, 제외수를 직접 지정할 수 있고... ",
# 			"bloggername":"코딩 읽어주는 아재 블로그",
# 			"bloggerlink":"blog.naver.com\/kkang2yah",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2024.10.08(화) 슈퍼코딩 부트캠프 신입연수원 Day 2 일일보고",
# 			"link":"https:\/\/blog.naver.com\/sunny5241\/223612026264",
# 			"description":"POST <b>파이썬<\/b>에서 DB 연결하기, DB는 sqlite3을 이용 &quot;&quot; &gt; &quot;&quot; &quot;&quot; &quot;&quot; &quot;&quot; &quot;&quot; &quot;&quot; &quot;&quot;&quot; &quot;&quot;&quot; cur.execute(f&quot;&quot;&quot; &quot;&quot;&quot;) : 따옴표... ▶ 저장된 게시글 확인하기 -GET, BLOB을 js에서 이미지로 변환해서 뿌려주기 <b>파이썬<\/b>에서... ",
# 			"bloggername":"개발공부",
# 			"bloggerlink":"blog.naver.com\/sunny5241",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"라즈베리파이와 MagicMirror를 이용한 스마트 달력 만들기... ",
# 			"link":"https:\/\/blog.naver.com\/lightblue99\/223612021053",
# 			"description":"<b>파이썬<\/b> 실행 화면과 TFT LCD화면은 아래와 같이 출력됩니다. 거의 다... 부팅이 되면 자동으로 오늘 작성한 <b>파이썬<\/b> 코드가 실행되도록 하는 부분을... ",
# 			"bloggername":"늘솔길의 쉬는 시간",
# 			"bloggerlink":"blog.naver.com\/lightblue99",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[무료 한글폰트] 눈누 기초고딕(2024)",
# 			"link":"https:\/\/blog.naver.com\/hp0\/223612016464",
# 			"description":"커버리지, <b>파이썬<\/b> 스크립트 등 제가 고안해낸 개발 지식 및 프로그래밍 기술까지 서체 개발에 적용하는 등 효율과 더불어 기술적인 향상도 이루어냈습니다. 3세대 엔진 연구노트 中 (2024) 매번... ",
# 			"bloggername":"유미주의적 달필가",
# 			"bloggerlink":"blog.naver.com\/hp0",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"ChatGPT를 활용한 아두이노, <b>파이썬<\/b> 프로그래밍 일대일... ",
# 			"link":"https:\/\/blog.naver.com\/cherrychance\/223612013614",
# 			"description":"kr\/curation-live-with-ai\/ 이러한 현실을 바탕으로 저는 프로그래밍의 핵심적인 언어인 아두이노와 <b>파이썬<\/b>을... 구축하거나, <b>파이썬<\/b>과 ChatGPT를 활용해 최적화된 운영 알고리즘을 제시할 수 있습니다. 이러한 새로운... ",
# 			"bloggername":"국내 유일한 코딩체험학습장 - 제로윈아트",
# 			"bloggerlink":"blog.naver.com\/cherrychance",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[죠스노트] 1~4주차 <b>파이썬<\/b> 수업내용 정리",
# 			"link":"https:\/\/blog.naver.com\/azsxdcfv246\/223612013557",
# 			"description":"<b>파이썬<\/b>은 그렇게 안 할 겁니다. 그 이유에 대해 얘기하자면요... 첫째, <b>파이썬<\/b>은 R보다 훨씬 접근성이 좋은 무료 강의가 많이 풀려 있어서 일개 교양 듣는 대학생 따위가 쓴 가이드라인을 볼 필요 따위... ",
# 			"bloggername":"겨울잠의 성소",
# 			"bloggerlink":"blog.naver.com\/azsxdcfv246",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"TQQQ 누적 수익률 및 분할매수 수익률 백테스트",
# 			"link":"https:\/\/blog.naver.com\/fin-pro\/223612012798",
# 			"description":"&quot;Yfinance&quot;란 야후 파이낸스(Yahoo Finance)에서 제공하는 금융 데이터를 <b>파이썬<\/b>에서 쉽게 사용할 수 있도록 해준다. 다음과 같이 'download'라는 함수로 간단히 원하는 데이터를 얻어올 수 있고 그... ",
# 			"bloggername":"금융프로그래머",
# 			"bloggerlink":"blog.naver.com\/fin-pro",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"사이드와인더 이 기능 없이는 못 살아 핵심 기능 3가지 비교 분석",
# 			"link":"https:\/\/blog.naver.com\/case9291\/223611999927",
# 			"description":"사이드와인더는 <b>파이썬<\/b> 개발자에게 있어서 없어서는 안 될 필수 도구입니다. 뛰어난 기능과 사용... 특히 <b>파이썬<\/b> 개발에 있어서 강력한 도구로 자리매김하고 있습니다. 뛰어난 기능과 사용 편의성으로 인해 전... ",
# 			"bloggername":"case9291님의 블로그",
# 			"bloggerlink":"blog.naver.com\/case9291",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"앱 개발 기초 프로그램 게임 코딩 배우기",
# 			"link":"https:\/\/blog.naver.com\/obeft1980\/223611993292",
# 			"description":"자바스크립트, <b>파이썬<\/b> 먼저 추천 C언어, C++ 등 다방면에서 목표에 맞게 배울 수 있습니다. 장점 현... <b>파이썬<\/b>(Python)으로 미션을 클리어하면서 데이터 분석에 대해 익히기 프로그램, 앱 개발 기초에 대해 관심이... ",
# 			"bloggername":"지혜의 공부이야기",
# 			"bloggerlink":"blog.naver.com\/obeft1980",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"python 기초, 변수",
# 			"link":"https:\/\/blog.naver.com\/hazel0727\/223611988388",
# 			"description":"<b>파이썬<\/b> 기초 자료형 : 변수의 형태 제어문 : 컴퓨터에게 제어를 내리는 명령문 함수 : 여러 줄의... 값 <b>파이썬<\/b>에서 '='는 변수를 저장할 때 사용, 등호는 '==' a,b = a에 저장할 값, b에 저장할 값 &gt; 한줄에... ",
# 			"bloggername":"아카이브 C",
# 			"bloggerlink":"blog.naver.com\/hazel0727",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>을 이용한 비트코인 자동매매(2)",
# 			"link":"https:\/\/blog.naver.com\/rrjscnfnr\/223611986006",
# 			"description":"#비트코인 #자동매매 #<b>파이썬<\/b> #코빗 #챗GPT 지난번에는 서명을 생성하고, 나의 자산을 조회하는 방법을 알아봤다면, 이번에는 코빗 API를 이용해서 시장가로 매수, 매도하는 함수를 만들어 보겠습니다.... ",
# 			"bloggername":"나미가 사는 세상",
# 			"bloggerlink":"blog.naver.com\/rrjscnfnr",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2024.10.08(화) 슈퍼코딩 부트캠프 신입연수원 Day 5 일일보고",
# 			"link":"https:\/\/blog.naver.com\/tpffk2555\/223611982336",
# 			"description":"- { 초보자 친화적 } \/ { 다양한 라이브러리와 프레임워크 } \/ { 거대한 커뮤니티 } -<b>파이썬<\/b> 세팅 및 기초 문법- { <b>파이썬<\/b> 설치 및 세팅 } \/ { 기초 문법 (자바스크립트와 비교) } -<b>파이썬<\/b> 설치- -VS... ",
# 			"bloggername":"tpffk2555님의블로그",
# 			"bloggerlink":"blog.naver.com\/tpffk2555",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"호매실 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/fary1991\/223611863878",
# 			"description":"호매실 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 이는 개발 속도를 빠르게 하고, 코드 작성의 유연성을 제공합니다. 광범위한 라이브러리 지원 <b>파이썬<\/b>은 풍부한 표준 라이브러리와... ",
# 			"bloggername":"fary1991님의 블로그",
# 			"bloggerlink":"blog.naver.com\/fary1991",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"비 그만 와",
# 			"link":"https:\/\/blog.naver.com\/rla_wabs\/223611976497",
# 			"description":"일단 아침에는 자고 있을 거 같고. 낮에 미적미적 일어나서 스테디커피나 오프더커프 가서 책 읽고 레포트 쓸 계획이고요. 저녁부터 밤까지는 도서관에서 <b>파이썬<\/b> 중간고사 실기 공부할 것입니다. 그럼 이만.",
# 			"bloggername":"아직 안 정함",
# 			"bloggerlink":"blog.naver.com\/rla_wabs",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"python 입문, 공부하면서 간단한 정리(파트1~파트5)",
# 			"link":"https:\/\/blog.naver.com\/wy_family\/223611974816",
# 			"description":"https:\/\/school.programmers.co.kr\/learn\/courses\/2 무료 <b>파이썬<\/b> 입문 강의를 듣기 시작했다. 그래도 대학때... <b>파이썬<\/b>에서, '' 작은따옴표, &quot;&quot; 큰따옴표 이거 둘다 혼용해서 쓴다. 아무 차이도 없다고 함. 작은... ",
# 			"bloggername":"wy_family님의 블로그",
# 			"bloggerlink":"blog.naver.com\/wy_family",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"팔달구 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/fary1991\/223611863805",
# 			"description":"팔달구 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 이러한 애플리케이션은 전체... <b>파이썬<\/b>이란 무엇인가? <b>파이썬<\/b>(Python)은 1991년 네덜란드의 프로그래머 귀도 반 팔달구<b>파이썬<\/b>... ",
# 			"bloggername":"fary1991님의 블로그",
# 			"bloggerlink":"blog.naver.com\/fary1991",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[2일차] ABC 부트 캠프 <b>파이썬<\/b> 기초(기본 함수, 인덱스)",
# 			"link":"https:\/\/blog.naver.com\/yunaaq\/223611968969",
# 			"description":"^^ 그래도 단백질 포기 못해ㅜ 오늘은 <b>파이썬<\/b>에 대한 첫 수업 날이었다. <b>파이썬<\/b>은 범용 프로그래밍 언어로 데이터 분석할 때 사용할 예정이라고 한다. 가장 많이 쓰는 프로그래밍 언어인데 그... ",
# 			"bloggername":"yunaaq님의 블로그",
# 			"bloggerlink":"blog.naver.com\/yunaaq",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"장안구 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/fary1991\/223611863751",
# 			"description":"장안구 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 이로 인해 전체 웹 애플리케이션을... 장안구<b>파이썬<\/b> 장안구<b>파이썬<\/b>학원 실행되므로 보안에 취약할 수 있습니다. 악의적인 사용자가... ",
# 			"bloggername":"fary1991님의 블로그",
# 			"bloggerlink":"blog.naver.com\/fary1991",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"의왕 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/fary1991\/223611863695",
# 			"description":"의왕 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 자바스크립트는 1995년 넷스케이프... 이를 통해 코드를 모듈화하고 재사용 가능하게 만들어 복잡한 의왕<b>파이썬<\/b> 의왕<b>파이썬<\/b>학원... ",
# 			"bloggername":"fary1991님의 블로그",
# 			"bloggerlink":"blog.naver.com\/fary1991",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"OpenAPI 찍먹하기, 키 발급, 간단한 사용 방법",
# 			"link":"https:\/\/blog.naver.com\/pinocchio5715\/223611948661",
# 			"description":"OpenAI API Key 발급 <b>파이썬<\/b>에서 랭체인과 openai를 설치하기 전에 먼저 해야 할 것은 API... 이용한 <b>파이썬<\/b> 코드 작성해보기 우선, <b>파이썬<\/b>에서 안전한 작업을 위해 가상환경을 하나 파서 랭체인과... ",
# 			"bloggername":"너와 나의 오늘",
# 			"bloggerlink":"blog.naver.com\/pinocchio5715",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"정보성 제목",
# 			"link":"https:\/\/blog.naver.com\/boabbka8173\/223611944042",
# 			"description":"예시: 좋은 '<b>파이썬<\/b> 프로그래밍 입문: 초보자를 위한 친절한 안내' 나쁜 '프로그래밍 배우기' 5. 감정을 자극하는 단어: 공감과 설득을 이끌어내는 힘 정보성 제목에 감정을 자극하는 단어를 사용하면 독자의... ",
# 			"bloggername":"진짜대박정보",
# 			"bloggerlink":"blog.naver.com\/boabbka8173",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"인덕원 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/fary1991\/223611863607",
# 			"description":"인덕원 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 또한, <b>파이썬<\/b>으로 작성된 코드는 별도의 수정 없이 다양한 환경에서 사용할 수 있기 때문에 개발자들이 시스템에 구애받지 않고 작업할 수... ",
# 			"bloggername":"fary1991님의 블로그",
# 			"bloggerlink":"blog.naver.com\/fary1991",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> pandas 데이터 프레임(dataframe)",
# 			"link":"https:\/\/blog.naver.com\/ifcode\/223611939902",
# 			"description":"데이터 프라임:다양한 자료를 이용하는 2차원 배열 1.딕셔너리를 데이터 프레임으로 변환하여 데이터 프레임 만들기 :pandas.Dataframe(딕셔너리 객체) &lt;실행예시&gt; mom tue wed thu... ",
# 			"bloggername":"if",
# 			"bloggerlink":"blog.naver.com\/ifcode",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"1008 탐색적데이터분석 수업노트",
# 			"link":"https:\/\/blog.naver.com\/24gostudy\/223611932096",
# 			"description":"근데 그걸 어떻게 그냥하면되는지 잘 모르겠다고 말씀드림 1 빅데이터분석기사 실기 -&gt; <b>파이썬<\/b>... 얘네들이 자체 개발한 트랙도 있어서 거기에도 문제있을거라고 **정리** <b>파이썬<\/b> 넘파이 -&gt; 문풀 웹크롤링... ",
# 			"bloggername":"24gostudy님의 블로그",
# 			"bloggerlink":"blog.naver.com\/24gostudy",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"여름끝부터 가을",
# 			"link":"https:\/\/blog.naver.com\/tpqls0202\/223611931808",
# 			"description":"그녀가 <b>파이썬<\/b> 그만하래 거기에 같이 살집 짓고 있는데 어디서부터 써야 될지 모루겟다 부산 갔던 거부터… ???: 그래 비도 오는데 걍 편점에서 술 사가지고 숙소 가서 마시자 돈도 아끼고 86,140 ???: 걍 술집 가는... ",
# 			"bloggername":"1240",
# 			"bloggerlink":"blog.naver.com\/tpqls0202",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"강남 신사동 압구정역 현대고 인근 국어 수학 영어 과학 학원... ",
# 			"link":"https:\/\/blog.naver.com\/myidok\/223611923562",
# 			"description":"블록체인학원, <b>파이썬<\/b>, 게임학원, 웹툰학원 웹크롤링, 웹스크래핑, 메타버스, 오픈AI학원 빅데이터, NFT 네이버큐, 하이퍼클로바 X (HyperCLOVA X) 노션AI, 뤼튼 AI, 미드저니, 구글바드 제미니 (제미나이) 코딩학원... ",
# 			"bloggername":"압구정_메디_에듀******",
# 			"bloggerlink":"blog.naver.com\/myidok",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"범계 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/songcou\/223611859241",
# 			"description":"범계 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS <b>파이썬<\/b>은 &quot;배터리가 포함된 언어&quot;라는 철학을 따르며, 수많은 라이브러리와 패키지를 기본으로 제공해 다양한 작업에 쉽게 활용할 수... ",
# 			"bloggername":"DELLY의 교육블로그",
# 			"bloggerlink":"blog.naver.com\/songcou",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"딥러닝\/강화학습 주식투자",
# 			"link":"https:\/\/blog.naver.com\/gomgun4781\/223611919375",
# 			"description":"&quot;<b>파이썬<\/b>과 케라스를 이용한 딥러닝\/강화학습 주식투자&quot; <b>파이썬<\/b>도 문법이 사실 가물가물하고, 케라스는 다뤄본 적도 없다. 또 이 모델을 개발해도, 어떻게 API로 만드는 지 아직은 모른다. 지금 보는 책의 초판... ",
# 			"bloggername":"곰군의 노트",
# 			"bloggerlink":"blog.naver.com\/gomgun4781",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[<b>파이썬<\/b>] 특정조건을 만족하는 행의 특정 열을 불러오기",
# 			"link":"https:\/\/blog.naver.com\/pjbmask\/223611915442",
# 			"description":"",
# 			"bloggername":"회계, 세무로 밥벌어 먹기",
# 			"bloggerlink":"blog.naver.com\/pjbmask",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"Week1-2. dbt 주요 개념2(Snapshots, Documentation... ",
# 			"link":"https:\/\/blog.naver.com\/analyticsdata\/223611915314",
# 			"description":"[3] Jinja + Macros Jinja: <b>파이썬<\/b> 템플릿 언어로 SQL과 함께 쓰여 SQL의 단점 보완 (If문, for문, 여러 환경 변수 등등) 일반적으로 {{}} 표기 --&gt; jinja Macros jinja코드의 일부로 다른 프로그래밍... ",
# 			"bloggername":"게임 데이터 분석( Data Analysis)",
# 			"bloggerlink":"blog.naver.com\/analyticsdata",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[<b>파이썬<\/b>] KRX에서 Close값 기준으로 가장 큰 5개 종목 추출",
# 			"link":"https:\/\/blog.naver.com\/pjbmask\/223611914651",
# 			"description":"&quot;&quot;",
# 			"bloggername":"회계, 세무로 밥벌어 먹기",
# 			"bloggerlink":"blog.naver.com\/pjbmask",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"평촌 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/songcou\/223611859194",
# 			"description":"평촌 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 이는 개발 비용을 절감하고 시간을... 디버깅의 어려움: 동적 타입 언어로 인해 런타임 오류가 평촌<b>파이썬<\/b> 발생할 수 있으며, 이로 인해... ",
# 			"bloggername":"DELLY의 교육블로그",
# 			"bloggerlink":"blog.naver.com\/songcou",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"송산신도시 코딩학원 일대일 코딩과외 <b>파이썬<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/songcou\/223611859143",
# 			"description":"송산신도시 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 이를 위해... 송산신도시<b>파이썬<\/b> 송산신도시<b>파이썬<\/b>학원 위해 이 언어를 활용하고 있습니다. 3.2 서버 사이드... ",
# 			"bloggername":"DELLY의 교육블로그",
# 			"bloggerlink":"blog.naver.com\/songcou",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"크롬 이전 버전 다운로드 방법과 크롬 자동 업데이트 방지 방법",
# 			"link":"https:\/\/blog.naver.com\/david_77777\/223611902001",
# 			"description":"오늘은 업무 자동화 관련 작업 중 <b>파이썬<\/b>과 셀레니움관련 글을 포스팅합니다. 건강 주식 부동산과... 제가 <b>파이썬<\/b>으로 셀레니움을 통해 네이버에 접속하려고 하는데 계속 오류가 나서 고민하여 하루... ",
# 			"bloggername":"HSRI(Health Stock Real estate Investment)",
# 			"bloggerlink":"blog.naver.com\/david_77777",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2024.10.08(화) 슈퍼코딩 부트캠프 신입연수원 Day 7 일일보고",
# 			"link":"https:\/\/blog.naver.com\/dnjsstgml\/223611900899",
# 			"description":"&lt;TO-DO LIST&gt; 32강~39강 강의듣기 실습한 wordle 게임을 배포(Netlify) python문법 백엔드 서버 만들기 <b>파이썬<\/b> 환경 세팅하기 &lt;오늘 배운 내용&gt; JavaScript 에서 HTML 태그 추가 const 변수명 = document.... ",
# 			"bloggername":"dnjsstgml님의블로그",
# 			"bloggerlink":"blog.naver.com\/dnjsstgml",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"핵심 정보 위주 제목",
# 			"link":"https:\/\/blog.naver.com\/monklsfhh132\/223611897894",
# 			"description":"위한 <b>파이썬<\/b> 프로그래밍 입문' (핵심 정보: <b>파이썬<\/b> 프로그래밍 입문, 초보자) 학술 논문: '인공지능 기반 의료 진단 시스템 개발 연구' (핵심 정보: 인공지능 기반 의료 진단 시스템 개발 연구) '기후 변화가 농업... ",
# 			"bloggername":"오빠감동이야",
# 			"bloggerlink":"blog.naver.com\/monklsfhh132",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"상록수 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/songcou\/223611859078",
# 			"description":"상록수 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS 5. <b>파이썬<\/b> 학습 방법 5.1 온라인 강의 Coursera, Udemy, edX 등의 플랫폼에서 다양한 <b>파이썬<\/b> 강의를 제공하고 있습니다. 초보자부터... ",
# 			"bloggername":"DELLY의 교육블로그",
# 			"bloggerlink":"blog.naver.com\/songcou",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"회귀(Regression)와 선형회귀(feat.최근접 이웃 알고리즘 k... ",
# 			"link":"https:\/\/blog.naver.com\/makersungt\/223611892682",
# 			"description":"추후 <b>파이썬<\/b>으로 실습할 경우, 관련 실습 내용도 함께 첨부하도록 하겠습니다. (이론 부분은 계속 자료를 개선할 예정) 머신러닝, 지도학습, 분류와 회귀 머신러닝 중 지도 학습 알고리즘은 분류와... ",
# 			"bloggername":"메이커 성쌤, 미래를 만드는 교실",
# 			"bloggerlink":"blog.naver.com\/makersungt",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[디지털 마케터 취업 준비] 도와세움 디마에 73기 5주차(2)",
# 			"link":"https:\/\/blog.naver.com\/chunsam_\/223611890121",
# 			"description":"아무튼 오늘의 수업은 <b>파이썬<\/b>, 포토샵, 네이버 검색광고였어요. <b>파이썬<\/b> 네……. 웹소 읽어요……. 웹소 추천해요……. 자동 출력되는거 너무 신기함. 수업중간에 갑좍 등장한 레서판다 반가와서 찍음. 그래요 저... ",
# 			"bloggername":"이것저것",
# 			"bloggerlink":"blog.naver.com\/chunsam_",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"고잔동 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C... ",
# 			"link":"https:\/\/blog.naver.com\/songcou\/223611859026",
# 			"description":"고잔동 코딩학원 일대일 코딩과외 <b>파이썬<\/b> 자바스크립트 C++ HTML CSS <b>파이썬<\/b>의 활용 분야 3.1 웹 개발 <b>파이썬<\/b>은 Django와 Flask와 같은 웹 프레임워크를 통해 웹 애플리케이션을 쉽게 개발할... ",
# 			"bloggername":"DELLY의 교육블로그",
# 			"bloggerlink":"blog.naver.com\/songcou",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"삼성 노트북 NT960XGLXD94G 최대특가 16인치 고해상도 AI... ",
# 			"link":"https:\/\/blog.naver.com\/ujyyrtrt344287\/223611880112",
# 			"description":"대학생들이 자주 사용하는 MS O365와 같은 오피스 프로그램, 코딩 및 데이터 분석을 위한 <b>파이썬<\/b>과 같은 소프트웨어도 무리 없이 실행 가능하다. 특히, AI 관련 과목을 수강하는 학생들에게는 딥러닝... ",
# 			"bloggername":"조시헌",
# 			"bloggerlink":"blog.naver.com\/ujyyrtrt344287",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"및 <b>파이썬<\/b> 활용 방법  챗GPT OpenAI 프로그래밍 할인... ",
# 			"link":"https:\/\/blog.naver.com\/xruonyrmd992\/223611861906",
# 			"description":"및 <b>파이썬<\/b> 활용 방법 챗GPT OpenAI 프로그래밍 할인 정보 오늘 소개할 제품은 단언컨데... ■ OpenAI API와 <b>파이썬<\/b>으로 나만의 챗GPT 만들기:ChatGPT 기초부터 OpenAI API 랭체인을 활용한 서비스 앱... ",
# 			"bloggername":"xruonyrmd992님의 블로그",
# 			"bloggerlink":"blog.naver.com\/xruonyrmd992",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[정보처리기사 실기 - 도전중]  Python 다운로드 및 설치 방법",
# 			"link":"https:\/\/blog.naver.com\/brilliantwy\/223611856872",
# 			"description":"<b>파이썬<\/b> 홈페이지 (https:\/\/www.python.org) 에 접속한다. 2. 홈페이지에서 ① Downloads 를 클릭한다. 3. ②... ③ py를 클릭하면 <b>파이썬<\/b>이 실행된다. 7. 아래 화면과 같이 실행되면 <b>파이썬<\/b> 프로그램이 제대로... ",
# 			"bloggername":"여유의 엉뚱한 취미생활",
# 			"bloggerlink":"blog.naver.com\/brilliantwy",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"암호화폐 만들기 위한 프로그래밍 언어",
# 			"link":"https:\/\/blog.naver.com\/flike3\/223611855904",
# 			"description":"<b>파이썬<\/b>의 간편함과 유연함 <b>파이썬<\/b>은 암호화폐 개발에서 점차 인기를 얻고 있는 언어입니다. 그 이유는 <b>파이썬<\/b>이 코드 작성이 쉽고 가독성이 높기 때문입니다. 특히, 블록체인 프로토타입 개발에 유용하며... ",
# 			"bloggername":"만기씨",
# 			"bloggerlink":"blog.naver.com\/flike3",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"AI 업데이트 ; 2024년 10월 첫째 주 - 영상 생성, 영상 효과 등... ",
# 			"link":"https:\/\/blog.naver.com\/mindstay701\/223611856124",
# 			"description":"특정 언어로 코드를 변환할 수 있으며, 예를 들어 <b>파이썬<\/b>으로 바꾸면 자동으로 적용된다. 새로운 기능들 덕분에 성능이 향상되었고, 오픈AI의 소라 개발자가 딥 마인드로 이직하여 구글 제품이 개선될... ",
# 			"bloggername":"마음놀이터의 마음백과사전",
# 			"bloggerlink":"blog.naver.com\/mindstay701",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 개인과제 2일차",
# 			"link":"https:\/\/blog.naver.com\/ohhalim777\/223611845099",
# 			"description":"필수과제 1. 숫자 맞추기 게임 ---- 플레이어와 컴퓨터가 참여하는 숫자 맞추기 게임을 만드세요. 프로그램은 다음과 같은 기능을 포함해야 합니다. 컴퓨터는 1부터 10... ",
# 			"bloggername":"ohhalim777님의블로그",
# 			"bloggerlink":"blog.naver.com\/ohhalim777",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"&lt;이마트 문화센터 충주점, SW 미래인재 코딩교육 강사 파견 제휴!&gt;",
# 			"link":"https:\/\/blog.naver.com\/adinsoft\/223611840902",
# 			"description":"앱인벤터 기반 SW 스마트폰 어플리케이션 개발자\/ 전문가 양성과정 프로그램 (웹\/앱 개발자의 다양한 직업소개 - 학교로 찾아가는 SW 교육) <b>파이썬<\/b>(Python) 기반 4차산업 데이터 분석 전문가 양성과정 프로그램... ",
# 			"bloggername":"(주)애드인소프트",
# 			"bloggerlink":"blog.naver.com\/adinsoft",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"통계분석은 R프로그래밍! 대전R빅데이터학원",
# 			"link":"https:\/\/blog.naver.com\/hxsgll1\/223611833476",
# 			"description":"또한 R프로그래밍은 오픈소스가 무료이고 여러 데이터베이스와 연동하거나 C++,<b>파이썬<\/b> 등 다른 언어와... R프로그래밍만 안다고 해서는 전혀 아니고 그 외 <b>파이썬<\/b>,DBMS도 알아야하기에 전문적으로 관련 학원에서... ",
# 			"bloggername":"초밥이 세상을 구한다",
# 			"bloggerlink":"blog.naver.com\/hxsgll1",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2025학년도 동덕여대 면접(feat.동덕창의리더전형) - 24.... ",
# 			"link":"https:\/\/blog.naver.com\/jinhakscience\/223611310148",
# 			"description":"정말 블록 코딩보다 <b>파이썬<\/b>이 쉬웠는가? 합성곱 연산이 뭔지 모르겠는데 설명해보겠는가? 정말 이해하고 만든게 맞는가? 코드를 가져와 만든건가? 마지막으로 하고 싶은 말 안녕하세요. 자기소개... ",
# 			"bloggername":"델타 입시자료실",
# 			"bloggerlink":"blog.naver.com\/jinhakscience",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2024년 9월의 한 달",
# 			"link":"https:\/\/blog.naver.com\/zayosh421\/223611823926",
# 			"description":"헤헤 <b>파이썬<\/b> 때려버려 이날은 둘째주 <b>파이썬<\/b> 두 번째 수업시간 ! 진짜 뭔소리인지 1도 모르겠구여 배워도 하나도 모르겠는 <b>파이썬<\/b>의 세계 ... 그래도 다음 수업 때부터는 괜찮아져서 다행이야.. 쭝이️ 저 수업... ",
# 			"bloggername":"DIARY",
# 			"bloggerlink":"blog.naver.com\/zayosh421",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 람다 함수",
# 			"link":"https:\/\/blog.naver.com\/jwyeyo\/223611821401",
# 			"description":"Python에서 람다(lambda) 함수는 일회성으로 사용될, 이름이 없는 간단한 함수들을 정의할 때 사용되는 아주 유용한 기능입니다. 이를 통해 코드의 가독성을 높이거나 불필요한 함수 정의를 줄일 수 있죠.... ",
# 			"bloggername":"JW Insights",
# 			"bloggerlink":"blog.naver.com\/jwyeyo",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"서면코딩국비지원 시대에 맞춘 자바언어 배우기",
# 			"link":"https:\/\/blog.naver.com\/itbestkdp20\/223611820374",
# 			"description":"ㅎㅎ 자바, <b>파이썬<\/b>, C언어 등 다양한 언어를 서면코딩국비지원 그린컴퓨터아카데미에서 배우면서 개발자취업에 한발짝 더 다가갈 수 있도록 실무경험과 교욱경험이 풍부한 강사님과 취업전문컨설팅선생님께서... ",
# 			"bloggername":"성공을 위해",
# 			"bloggerlink":"blog.naver.com\/itbestkdp20",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"대전자바학원 4차산업혁명의 시작",
# 			"link":"https:\/\/blog.naver.com\/nnnjky\/223611819424",
# 			"description":"기본적인 언어 문법부터 프로그래밍 개발에 있어서 기술역량 심화까지 공부를 체계적으로 할 수 있다는 장점과 자바언어를 제외한 <b>파이썬<\/b>, C언어, HTML, CSS 등 다양한 기초언어를 마찬가지의 기초부터... ",
# 			"bloggername":"권이의 블로그",
# 			"bloggerlink":"blog.naver.com\/nnnjky",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"이터레이터란? <b>파이썬<\/b>의 반복자를 쉽게 이해해보자!",
# 			"link":"https:\/\/blog.naver.com\/jwyeyo\/223611810090",
# 			"description":"<b>파이썬<\/b>을 공부하다 보면 &quot;이터레이터(iterator)&quot;라는 용어를 들어본 적이 있을 거예요. 이터레이터는 <b>파이썬<\/b>에서 반복 작업을 할 때 아주 중요한 역할을 해요. 오늘은 이터레이터가 무엇인지, 어떻게... ",
# 			"bloggername":"JW Insights",
# 			"bloggerlink":"blog.naver.com\/jwyeyo",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"매직아이",
# 			"link":"https:\/\/blog.naver.com\/delkin_workspace\/223611808330",
# 			"description":"오토스테레오그램 이라고 하더라. 눈이 2개라서 생기는 현상이고, 원래 물체를 보던 방식과 다르게 표면의 뒤 혹은 앞을 초점으로 하고 보면 깊이가 다르게 보이는 이미지를... ",
# 			"bloggername":"workspace",
# 			"bloggerlink":"blog.naver.com\/delkin_workspace",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"인천서구코딩학원 코딩종류와 각 언어별 특징",
# 			"link":"https:\/\/blog.naver.com\/baebully0986\/223611804255",
# 			"description":"기초 언어는 C언어,자바,<b>파이썬<\/b> 이 언어들을 기초 코딩 삼대장이라고 부릅니다. C언어 C언어는... <b>파이썬<\/b> 인천서구코딩학원 <b>파이썬<\/b>은 가장 최근에 나온 언어에요! 그렇다보니 이전 언어들의 단점은 보완을 하고... ",
# 			"bloggername":"도리님의 블로그",
# 			"bloggerlink":"blog.naver.com\/baebully0986",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"회사취업 지입차 자격조건 다양한 일자리 고정 1200만원",
# 			"link":"https:\/\/blog.naver.com\/egg14920\/223611802946",
# 			"description":"C언어는 가장 먼저 C언어와 JAVA, <b>파이썬<\/b>, C++ 등의 방법을 알아보기 시작했습니다! 정말 많았잖아요? 간단하게 말하면 좋을지 수정해 주셨습니다. 3. 회사취업 그러다 결국엔 방향을 확실히 바뀐 결과물을 두... ",
# 			"bloggername":"egg14920님의 블로그",
# 			"bloggerlink":"blog.naver.com\/egg14920",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"모두 모여라! 쉽고 재밌는 코딩하러 가자!",
# 			"link":"https:\/\/blog.naver.com\/ash1106219\/223611801552",
# 			"description":"초등학교 고학년부터 체험하기 적합한 텍스트코딩 부문에서는 코딩 임무를 <b>파이썬<\/b>, JAVA, C, C++ 등의... 고 ㈜엘리스그룹 <b>파이썬<\/b> 데이터 분석 문제집 중학생 이상 ㈜엘리스그룹 인공지능 (6개) 인공지능... ",
# 			"bloggername":"JOHN의 일상노트",
# 			"bloggerlink":"blog.naver.com\/ash1106219",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"모두 모여라! 쉽고 재밌는 코딩하러 가자!",
# 			"link":"https:\/\/blog.naver.com\/ash1106\/223611799787",
# 			"description":"초등학교 고학년부터 체험하기 적합한 텍스트코딩 부문에서는 코딩 임무를 <b>파이썬<\/b>, JAVA, C, C++ 등의... 고 ㈜엘리스그룹 <b>파이썬<\/b> 데이터 분석 문제집 중학생 이상 ㈜엘리스그룹 인공지능 (6개) 인공지능... ",
# 			"bloggername":"정책정보, 지원사업, 캠핑, 경제 등 우빗거리다",
# 			"bloggerlink":"blog.naver.com\/ash1106",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>-12차시(리스트,튜플)",
# 			"link":"https:\/\/blog.naver.com\/jeongmink0627\/223611799254",
# 			"description":"리스트 정렬 시 sort()는 리스트 자체를 바꾸고, sorted()는 새로운 리스트를 만든다. 리스트 연결 시 +연산자는 연결된 새로운 리스트를 만들고, extend는 한 리스트의 끝에 다른 리스트를 연결한다. 큐플은... ",
# 			"bloggername":"jeongmin",
# 			"bloggerlink":"blog.naver.com\/jeongmink0627",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"정보 제공형 제목",
# 			"link":"https:\/\/blog.naver.com\/oajfladfn512\/223611795939",
# 			"description":"'초보자를 위한 <b>파이썬<\/b> 프로그래밍 입문: 기초 문법부터 실전 프로젝트까지' - 대상 독자(초보자)와 콘텐츠 범위(기초 문법부터 실전 프로젝트)를 명확히 제시합니다. '2023년 주식 투자 트렌드 분석: 성장 가능성... ",
# 			"bloggername":"회생정보뱅크",
# 			"bloggerlink":"blog.naver.com\/oajfladfn512",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"야빠일상",
# 			"link":"https:\/\/blog.naver.com\/llilill_\/223611787009",
# 			"description":"요샌 <b>파이썬<\/b> 배우는데 정보 선생님 혼자 갑자기 부산 어쩌구저쩌구 하길래 한귀로 듣고 한귀로 흘림. 정보 수업을 딱히 좋아하진 않는데 <b>파이썬<\/b> 배우는 건 재밌어서 열심히 듣고 있다. 내 책상 상태 ㅁㅊ거... ",
# 			"bloggername":"˚‧｡♥｡‧˚",
# 			"bloggerlink":"blog.naver.com\/llilill_",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"프로그래머스 데브코스 데이터 엔지니어링 TIL #14일차... ",
# 			"link":"https:\/\/blog.naver.com\/tkdhfl8870\/223611778702",
# 			"description":"Django <b>파이썬<\/b> 웹 프레임워크. <b>파이썬<\/b>으로 웹을 만들 때 사용한다. 가상환경: 하나의 pc에 서로 다른 버전의 <b>파이썬<\/b>과 라이브러리를 사용할 수 있다. 여러 개발자가 함께... ",
# 			"bloggername":"연두의 블로그",
# 			"bloggerlink":"blog.naver.com\/tkdhfl8870",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"리스트 컴프리헨션(List comprehension)",
# 			"link":"https:\/\/blog.naver.com\/jwyeyo\/223611777594",
# 			"description":"<b>파이썬<\/b>을 사용하다 보면 반복문과 조건문을 활용해 리스트를 생성하는 일이 빈번하게 발생합니다. <b>파이썬<\/b>은 이런 작업을 간결하고 효율적으로 처리할 수 있는 기능을 제공합니다. 바로 **리스트... ",
# 			"bloggername":"JW Insights",
# 			"bloggerlink":"blog.naver.com\/jwyeyo",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"2-1. Python 기본 Interpreter 설치(Windows기준)",
# 			"link":"https:\/\/blog.naver.com\/knowzhegenage\/223611321333",
# 			"description":"설치 다운로드: 네이버에서 &quot;<b>파이썬<\/b>&quot; 또는 &quot;Python&quot; 검색하여 공식 페이지의 다운로드 페이지 클릭 &lt;네이버에 &quot;<b>파이썬<\/b>&quot;으로 검색했을때: 광고가 우선 나오기 때문에 스크롤을 내려서 Python 공식... ",
# 			"bloggername":"이것저것알아보자",
# 			"bloggerlink":"blog.naver.com\/knowzhegenage",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 체크버튼 활용하기, 따옴표 속 따옴표 사용하기",
# 			"link":"https:\/\/blog.naver.com\/kijiy11\/223611774717",
# 			"description":"체크버튼이란? 체크를 할 수 있는 버튼이다.(복수선택 가능) 체크버튼의 경우 .get() 을 사용할 수 없어 IntVar() 로 대체해서 코딩해야한다. &lt;&gt; &lt;&lt;&quot; &quot; &quot; &quot; &quot; &quot; &lt;&gt; &quot; &quot; 목표: 각 코딩 언어별 Hello World 출력을 나타내는... ",
# 			"bloggername":"물사조의블로그",
# 			"bloggerlink":"blog.naver.com\/kijiy11",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"앳래나 아틀랜타 백투더 스테이트 저스티스 컴백홈 아틀랜타... ",
# 			"link":"https:\/\/blog.naver.com\/jojjs777\/223611762462",
# 			"description":"나와 같은 융합전공 (interdiciplinary studies), 한국말로 융합인재학과 출신인 나로써는 데이터에 관해서는 진짜 맛뵈기로 <b>파이썬<\/b>이나 끄적거리는게 전부였는데, 데이터 관리자, 소프트웨어 개발자의 삶이... ",
# 			"bloggername":"미칠왕의 모1험",
# 			"bloggerlink":"blog.naver.com\/jojjs777",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"print문과 주석",
# 			"link":"https:\/\/blog.naver.com\/sooimz77\/223611761721",
# 			"description":"print문 <b>파이썬<\/b>에서는 print를 이용하면 데이터를 출력할 수 있음 &gt; 화면이 메세지를 보여줌 print... 않으며, <b>파이썬<\/b> 실행 시 제외됨 ex) # 이 부분은 주석입니다 print('Hello, World') # 이 코드 줄은 &quot;Hello... ",
# 			"bloggername":"짱이 될거야",
# 			"bloggerlink":"blog.naver.com\/sooimz77",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[퍼포먼스 마케터 취업 준비] 도와세움 디마에 73기 수업 - 쉬다... ",
# 			"link":"https:\/\/blog.naver.com\/marketer_ramong\/223611723648",
# 			"description":"5cm 가름끈 길이 고무줄 길이 북 커버 안쪽 넓이 동대문 시장 가서 할 일 가름끈 종류 교체 고무줄 색상 교체 단추 사이즈 변경 &lt; <b>파이썬<\/b> 수업 &gt; 예전에 <b>파이썬<\/b> 공부를 한 적이 있어서 비교적 가벼운... ",
# 			"bloggername":"취뽀",
# 			"bloggerlink":"blog.naver.com\/marketer_ramong",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[인사이트 캠퍼스X새싹 종로캠] 청년취업사관학교 종로캠... ",
# 			"link":"https:\/\/blog.naver.com\/fininsight\/223611738036",
# 			"description":"(단, 고용보험 미가입자 대상으로 진행) 해당 과정을 통해 <b>파이썬<\/b> 프로그래밍 기초 뿐만 아니라 데이터 수집 및 분석 그리고 서비스 기획 역량까지 습득해가실 수 있다는 점!! 데이터 분석과 서비스 기획 두... ",
# 			"bloggername":"핀인사이트 (Fininsight)",
# 			"bloggerlink":"blog.naver.com\/fininsight",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"챗GPT 캔버스 기능과 사용법 소개 : 새로운 글쓰기와 코딩에... ",
# 			"link":"https:\/\/blog.naver.com\/mkzzung\/223611734430",
# 			"description":"캔버스 화면 내 우측에 단축키를 통해 자바스크립트, <b>파이썬<\/b>, PHP 등 원하는 언어로 바꿔줄 수 있는 기능도 있는데 클릭 한번만으로 프로그래밍 언어를 바꿔주는데 기능은 정말 놀랍더라고요. 이를 구현하기... ",
# 			"bloggername":"AI 마케팅 랩스 ♡ AI, IT, 퍼널 마케팅 자동화",
# 			"bloggerlink":"blog.naver.com\/mkzzung",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[대치동 코딩학원 발명품 대회 특강] 발명품 경진대회 대비 특강",
# 			"link":"https:\/\/blog.naver.com\/akeocoding\/223611732464",
# 			"description":"안녕하세요  한 번 물면 놓지 않는다! 대치동 코딩학원 악어코딩입니다  악어코딩에서 발명품 경진대회를 대비하는 [발명품경진대회 대비 특강]을 오픈했습니다. 주제 선정, 프로그래밍을 통한 작품 제작... ",
# 			"bloggername":"악어코딩",
# 			"bloggerlink":"blog.naver.com\/akeocoding",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"소상공인시장진흥공단 직원 대상 '데이터 분석 기초와... ",
# 			"link":"https:\/\/blog.naver.com\/gptman\/223611729020",
# 			"description":"통한 <b>파이썬<\/b> 환경 설정 및 기초 사용법 - ChatGPT와 함께 활용하면 좋은 도구 소개 - ChatGPT를 활용한 업무 효율성 향상 보고서 작성 실습 특히, ChatGPT로 고객 민원에 대응하는 이메일을 작성하고, 코드... ",
# 			"bloggername":"챗GPT 강사 지피티맨",
# 			"bloggerlink":"blog.naver.com\/gptman",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[구로IT취업교육] 2024 하반기 기초부터 취업까지_국비지원... ",
# 			"link":"https:\/\/blog.naver.com\/grtjoeun\/223611728227",
# 			"description":"AWS 풀스택 웹앱(자바, 스프링, 리액트) 지역산업기반 개발자 양성 빅데이터(<b>파이썬<\/b>) 분석 기반 AI(머신러닝, 딥러닝) &amp; 추천 알고리즘 개발 <b>파이썬<\/b>&amp;앤서블로 시작하는 클라우드 인프라(데브옵스) 전문가... ",
# 			"bloggername":"더조은컴퓨터학원 구로캠퍼스",
# 			"bloggerlink":"blog.naver.com\/grtjoeun",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"토토가 신청 매크로| 자동화로 시간 절약하는 꿀팁 | 토토... ",
# 			"link":"https:\/\/blog.naver.com\/honeytips1048\/223611726692",
# 			"description":"예를 들어, <b>파이썬<\/b>과 selenium 등의 라이브러리를 활용하여 웹 브라우저를 제어하고 토토 신청 작업을 자동화 할 수 있습니다. 다만, 매크로를 직접 제작하는 것은 전문 지식을 필요로 하므로, 초보자의 경우 매크로... ",
# 			"bloggername":"꿀정보",
# 			"bloggerlink":"blog.naver.com\/honeytips1048",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"국민 내일배움카드 신청자격 및 신청방법 (근로자+재직자+구직자)",
# 			"link":"https:\/\/blog.naver.com\/nothing1807\/223611719650",
# 			"description":"<b>파이썬<\/b>, 자바, C++ 등 다양한 프로그래밍 언어 교육을 통해 실제 프로젝트 개발 경험을 쌓을 수 있습니다. 2. 실업 후 훈련 과정: * 대상: 실업 상태에 있는 구직자로, 새로운 직업을 찾거나 기존 직무 능력을... ",
# 			"bloggername":"nothing1807님의 블로그",
# 			"bloggerlink":"blog.naver.com\/nothing1807",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"문과생이 웹개발자가 될 수 있을까? (java, python 공부하기)",
# 			"link":"https:\/\/blog.naver.com\/junemonth06\/223611717722",
# 			"description":"자바와 <b>파이썬<\/b> 공부를 어떻게 시작해야 될 지 모르겠다 하시면 부산예일직업전문학교에 오세요 ! 수강료 0원 교재비 0원 매월 훈련장려금 지급(최대 81만 6천원) 웹개발에 대한 이론과 실습, 포트폴리오... ",
# 			"bloggername":"공부하고 취업하고",
# 			"bloggerlink":"blog.naver.com\/junemonth06",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"인천직업훈련학원 연희직업전문학교에서 전액 무료로 배우는... ",
# 			"link":"https:\/\/blog.naver.com\/yh_001\/223611714778",
# 			"description":"#AIOT #IOT #사물인터넷 #인천서구전액무료 #인천서구취업교육 #국민내일배움카드 #산업구조변화대응 #산대특 #자바 #<b>파이썬<\/b> #AIoT #IoT #웹개발자 #JAVA #웹개발 #C언어 #인천국비교육 #인천국비무료... ",
# 			"bloggername":"연희직업전문학교 인천 IT 국비지원 BHA훈련기관",
# 			"bloggerlink":"blog.naver.com\/yh_001",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"16일차(241008) : 자바 Map, Set, TreeSet과 TreeMap... ",
# 			"link":"https:\/\/blog.naver.com\/thx_log\/223611715109",
# 			"description":"제대로 작동하는지 테스트 &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; <b>파이썬<\/b>으로 해본 예제 강사님 해설... 종료 <b>파이썬<\/b>으로 해본 예제 화려... ",
# 			"bloggername":"착장변경",
# 			"bloggerlink":"blog.naver.com\/thx_log",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"Lv.2 괄호 변환 - <b>파이썬<\/b> 풀이 \/ 2020 카카오 블라인드 채용... ",
# 			"link":"https:\/\/blog.naver.com\/jmc0820\/223611715431",
# 			"description":"&quot;&quot; &quot;&quot; 1. 입력이 빈 문자열인 경우, 빈 문자열을 반환합니다. 2. 문자열 w를 두 &quot;균형잡힌 괄호 문자열&quot; u, v로 분리합니다. 단, u는 &quot;균형잡힌 괄호 문자열&quot;로 더 이상 분리할 수 없어야 하며, v는 빈 문자열이 될... ",
# 			"bloggername":"코코네 블로그",
# 			"bloggerlink":"blog.naver.com\/jmc0820",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 공부 한 것들 (1)",
# 			"link":"https:\/\/blog.naver.com\/songbam_48\/223611713320",
# 			"description":"첨부파일 1.py 코딩하기 귀찮다..... #코딩 #<b>파이썬<\/b> #공부 #컴퓨터",
# 			"bloggername":"songbam_48님의 블로그",
# 			"bloggerlink":"blog.naver.com\/songbam_48",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>: Checkbox",
# 			"link":"https:\/\/blog.naver.com\/ellie2435\/223611695715",
# 			"description":"여러분!!!! 제가 오랜만에 돌아왔어요! 제가 학교에서 바쁜 일이 생겨서 이제서야 돌아왔습니다. 분명 매번 금방 돌아오겠다고 약속하는데.... 죄송합니다! 오늘은 제가 Checkbox라는 기능을 사용해서... ",
# 			"bloggername":"YES님의 블로그",
# 			"bloggerlink":"blog.naver.com\/ellie2435",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b>",
# 			"link":"https:\/\/blog.naver.com\/leeyonsong3382\/223611691507",
# 			"description":"def add_data(friend): katok.append(None) kLen=len(katok) katok[kLen-1]=friend def insert_data(position,friend): katok.append(None) kLen=len(katok) katok[kLen-1]=friend def insert_data(position)... ",
# 			"bloggername":"leeyonsong3382님의블로그",
# 			"bloggerlink":"blog.naver.com\/leeyonsong3382",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"추천시스템 Week 2 : precision@k, recall@k, F1 <b>파이썬<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/importpandas\/223611690064",
# 			"description":"문제 온라인 쇼핑몰에서 사용자가 관심을 가질 만한 상품을 추천했다. 추천한 상품은 위에서부터 순서대로 [2번, 100번, 30번, 44번] 상품이고, 사용자가 실제로 구매한 상품은 [1번, 100번, 40번, 20번... ",
# 			"bloggername":"AI대학원 석사하면 AI전문가 되나요",
# 			"bloggerlink":"blog.naver.com\/importpandas",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"[LG전자 DX SCHOOL] 우당탕탕 디엑스 스쿨 특별편 - 홍대... ",
# 			"link":"https:\/\/blog.naver.com\/na_airy\/223611682834",
# 			"description":"LG전자 DX School 교육장인 홍대 DX러닝센터를 소개해보도록 하겠습니다 ㅋ . . . DX러닝센터는 서울시 마포구 양화로 196 동성빌딩 4층 에 위치하고 있음 . . . 들어오면 짜잔 면접도 여기서 봄 다 같이 로비에... ",
# 			"bloggername":"나블나블",
# 			"bloggerlink":"blog.naver.com\/na_airy",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"<b>파이썬<\/b> 설치하는 방법과 과정",
# 			"link":"https:\/\/blog.naver.com\/mhna98\/223611682714",
# 			"description":"<b>파이썬<\/b> 설치하는 방법과 과정 &amp; <b>파이썬<\/b> 설치 방법 1 <b>파이썬<\/b>을 설치하는 방법에 대해 알아보겠습니다. 공식 웹 사이트 방문: 먼저 <b>파이썬<\/b>의 공식 웹 사이트에 접속합니다. 다운로드: 웹 사이트에서 원하는... ",
# 			"bloggername":"라오유튜브",
# 			"bloggerlink":"blog.naver.com\/mhna98",
# 			"postdate":"20241008"
# 		},
# 		{
# 			"title":"부산빅데이터학원 웹개발자 취업을 위한 국비 무료 교육 교육생... ",
# 			"link":"https:\/\/blog.naver.com\/ds3400\/223611681540",
# 			"description":"개념, <b>파이썬<\/b> 기초, 데이터 크롤링 방법을 익힌 후 목표 설정 → 데이터 수집 → 데이터 준비 → 데이터 탐색 → 데이터 모델링 → 결과 시각화 순의 데이터 과학 방법론에 따라 실습 통계 분석, 텍스트 빈도... ",
# 			"bloggername":"동성인재개발교육원",
# 			"bloggerlink":"blog.naver.com\/ds3400",
# 			"postdate":"20241008"
# 		}
# 	]
# }
